# %%
import os
import pandas as pd 
import json
from pprint import pprint

# %%
initial_frame = "../data/clean/regional-us-weekly-enriched.csv"

frame_df = pd.read_csv(initial_frame)

frame_df.head()
result = frame_df.sort(['Streams'], ascending=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-77fb746e0419> in <module>()
#       4
#       5 frame_df.head()
# ----> 6 result = frame_df.sort(['Streams'], ascending=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
initial_frame = "../data/clean/forgotify-10-enriched.csv"

frame_df = pd.read_csv(initial_frame)

frame_df.head()
# Out:
#    Unnamed: 0  Position         Artist                       Title  \
# 0           0         1  Alex Kiskachi             On Land and Sea
# 1           1         2    Ragged Jack       What We've Got Coming
# 2           2         3        Kidzone                   Dem Bones
# 3           3         4   Armen Firman             Dressed For War
# 4           4         5   Dave Hancock  It Might As Well Be Spring
#
#    Acousticness                                 Album  Danceability  \
# 0         0.740               Unfaithful Syncopations         0.747
# 1         0.133                       Life Is A Wheel         0.568
# 2         0.163  Songs for Having Fun With My Friends         0.820
# 3         0.228                       Dressed For War         0.488
# 4         0.962                        Out of Nowhere         0.402
#
#    Duration (ms)  Energy  Explicit   ...    Key  Liveness  Loudness  Mode  \
# 0         260667  0.2060     False   ...      4    0.1180   -17.181     0
# ...

# %%
initial_frame = "../data/clean/2018-worst-songs-enriched.csv"

frame_df = pd.read_csv(initial_frame)

frame_df.head(10)
# Out:
#    Unnamed: 0  Position                   Artist  \
# 0           0         1              Post Malone
# 1           1         2                  6ix9ine
# 2           2         3             Bella Thorne
# 3           3         4        Justin Timberlake
# 4           4         5                 Maroon 5
# 5           5         6                     Zayn
# 6           6         7                 DJ Snake
# 7           7         8  Kanye West and Lil Pump
# 8           8         9          Greta Van Fleet
# 9           9        10                   Eminem
#
#                                            Title  Acousticness  \
# 0                   Psycho (feat. Ty Dolla $ign)       0.58000
# 1         FEFE (feat. Nicki Minaj & Murda Beatz)       0.09080
# 2                         B*TCH I’M BELLA THORNE       0.25300
# 3                                 The Hard Stuff       0.15200
# 4                 Girls Like You (feat. Cardi B)       0.56800
# ...
